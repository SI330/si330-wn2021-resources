# %% [markdown]
# # Apply (or, thinking and doing functionally)
# - We've talked at length about the benefits of broadcasting and vectorization, but sometimes you need to do something that NumPy just can't do
# - We can still think and act functionally, and pandas provides two mechanisms for this `apply` and `applymap`

# %%
# %load_ext fakermaker
import fakermaker

# %% [markdown]
# - `applymap` is a function on a `DataFrame` which takes a single parameter: some function to apply to all cells in the `DataFrame`
# - The return value is, likewise, simple: the new `DataFrame`
# - Let's take a look

# %%
# %%fakermaker
# person
# ---------
# ssn
# random_number(digits=5) as cash_on_hand
# Out:
# ---------------------------------------------------------------------------
# FakeDataFrameParserException              Traceback (most recent call last)
# <ipython-input-7-341a3f8f9ac8> in <module>
# ----> 1 get_ipython().run_cell_magic('fakermaker', '', 'person\n---------\nssn \nrandom_number(digits=5) as cash_on_hand\n')
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# </opt/conda/lib/python3.7/site-packages/decorator.py:decorator-gen-126> in fakermaker(self, line, cell, local_ns)
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/conda/lib/python3.7/site-packages/fakermaker/faker_maker.py in fakermaker(self, line, cell, local_ns)
#     275         if 'seed' in params:
#     276             cls.seed(int(params['seed']))
# --> 277         cls.parse()
#     278         for name, df in cls.dataframes.items():
#     279             local_ns[name] = df
#
# /opt/conda/lib/python3.7/site-packages/fakermaker/faker_maker.py in parse(self)
#     228                         parts = [item.groupdict() for item in re.finditer(self.__field_matcher,line,re.VERBOSE)]
#     229                         if len(parts) < 1:
# --> 230                             raise FakeDataFrameParserException(f'Unparsable field line: {line}')
#     231                         else:
#     232                             if parts[0]['field_name'] is None:
#
# FakeDataFrameParserException: Unparsable field line: ssn

# %%
person
# Out:
#             ssn  cash_on_hand
# 0   881-09-6726         22663
# 1   277-99-8368         55387
# 2   307-14-0258         94541
# 3   692-16-7070          3271
# 4   623-12-6562         24213
# ..          ...           ...
# 94  231-34-9884         93809
# 95  750-96-3367         55584
# 96  097-43-0428         82997
# 97  623-12-6562         49015
# 98  822-01-6185         93879
#
# [99 rows x 2 columns]

# %% [markdown]
# - In the end, I almost never use `applymap`, but `apply` I use on **every** data cleaning approach
# - `apply` looks almost the same, but acts across a row or column
# - **very very powerful**
# - the result of an apply is a `Series` or `DataFrame` object

# %%
# %%fakermaker
# people
# ------
# name
# address

# %%
people.head()

# %% [markdown]
# - So, how should we clean this?
# - Let's break everything apart!

# %%
def get_zip(row):
    '''This function expects a parameter called row which is of type Series.
    The expectation is that the Series object has two fields in it, one for
    the name of a person and one for the address of the person. This function
    will pull out and return the zip code for the address'''
    # little tests to make sure our row is formatted properly
    
    
    #Let's use a regex to find the zip code!

# %%
people

# %% [markdown]
# Let's try one more example...with even more addresses!

# %%
# %%fakermaker
# person_info
# -----------
# address as home
# address as work
# address as school
# ssn
